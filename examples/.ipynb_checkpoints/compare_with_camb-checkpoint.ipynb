# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, platform, os
import matplotlib
from matplotlib import pyplot as plt
import numpy as np

#Assume installed from github using "git clone --recursive https://github.com/cmbant/CAMB.git"
#This file is then in the docs folders
camb_path = os.path.realpath(os.path.join(os.getcwd(),'..'))
sys.path.insert(0,camb_path)
import camb
from camb import model, initialpower
print('Using CAMB %s installed at %s'%(camb.__version__,os.path.dirname(camb.__file__)))
# Out:
# Using CAMB 0.1.6.1 installed at /home/yanza15/.local/lib/python2.7/site-packages/camb

# %%
sys.path.append('/home/yanza15/software/Compos_new/sources')
import compos_new as compos
reload(compos)
# Out:
# <module 'compos_new' from '/home/yanza15/software/Compos_new/sources/compos_new.pyc'>

# %%
omb = 0.04826
omc = 0.25
omk = 0
om0 = omb + omc
omq = 1 - om0
TCMB = 2.7255

H0 = 67.77
h = H0 / 100.
ombh2 = omb * h ** 2
omch2 = omc * h ** 2
omk = 0
ns = 0.96

# %%
#Set up a new set of parameters for CAMB
pars = camb.CAMBparams()
#This function sets up CosmoMC-like settings,
#with one massive neutrino and helium set using BBN consistency
pars.set_cosmology(H0=H0, ombh2=ombh2, omch2=omch2, mnu=0.0, omk=omk,num_massive_neutrinos=0,
                   nnu=3, YHe=None, meffsterile=0.0,
                   standard_neutrino_neff=3., tau=0.0, 
                   TCMB=TCMB)
pars.InitPower.set_params(ns=ns, r=0)

# %%
pars.set_matter_power(redshifts=[0., 2., 4], kmax=10)
pars.NonLinear = model.NonLinear_none
results = camb.get_results(pars)
kh, z, lpk_camb = results.get_matter_power_spectrum(minkh=1e-4, maxkh=10, npoints = 200)
# Out:
# Note: redshifts have been re-sorted (earliest first)

# %%
tf = results.get_matter_transfer_data()
kh_tf = tf.transfer_data[0,:,0]
delta = tf.transfer_data[model.Transfer_tot-1,:,0]

# %%
# Out:
# 0.04826

# %%
s8 = tf.sigma_8
lp_class = compos.matterps(om0 = om0, omb=omb, H=H0, T_CMB=TCMB, omq=omq, Z=0,
                           sigma8=s8[-1][0])

# %%
plt.loglog(kh_tf, delta/delta[0],label = 'CAMB')
plt.loglog(kh_tf, lp_class.transfunction(kh_tf*h), label='COMPOS')
plt.legend()

# %%
reload(compos)
k = kh * h

lpk_compos_0 = lp_class.normalizedmp(k)
lpk_compos_2 = lp_class.normalizedmp(k, z=2)
lpk_compos_4 = lp_class.normalizedmp(k, z=4)

# %%
from matplotlib import gridspec

fig = plt.figure(figsize=(7,7))
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 1]) 

ax1 = plt.subplot(gs[0])
ax1.loglog(kh, lpk_camb[0], color = 'C0', label='CAMB, Z=0')
ax1.loglog(kh, lpk_compos_0*h**3, color = 'C1', label='COMPOS, Z=0')

ax1.loglog(kh, lpk_camb[1], color = 'C2', label='CAMB, Z=2')
ax1.loglog(kh, lpk_compos_2*h**3, color = 'C3', label='COMPOS, Z=2')

ax1.loglog(kh, lpk_camb[2], color = 'C4', label='CAMB, Z=4')
ax1.loglog(kh, lpk_compos_4*h**3, color = 'C5', label='COMPOS, Z=4')
ax1.legend()
ax1.grid()
ax1.xaxis.set_ticklabels([])
ax1.set_ylabel(r'$P(k)(\mathrm{h^{-1}Mpc})^3$',fontsize=12)
ax2 = plt.subplot(gs[1])
ax2.semilogx(kh, (lpk_camb[0]-(lpk_compos_0*h**3)) / lpk_camb[0]*100, color='C0', label='Z=0')
ax2.semilogx(kh, (lpk_camb[1]-(lpk_compos_2*h**3)) / lpk_camb[1]*100, color='C2', label='Z=2')
ax2.semilogx(kh, (lpk_camb[2]-(lpk_compos_4*h**3)) / lpk_camb[2]*100, color='C4', label='Z=4')
ax2.legend()
ax2.set_ylim(-5, 5)
ax2.grid()
ax2.set_xlabel(r'$k(\mathrm{h^{-1}Mpc})$',fontsize=12)
ax2.set_ylabel(r'$\Delta(\%)$')
plt.subplots_adjust(hspace=0)

# %%
pars.set_matter_power(redshifts=[0., 2., 4], kmax=1e3)
pars.NonLinear = model.NonLinear_both
results = camb.get_results(pars)
kh, z, nlpk_camb = results.get_matter_power_spectrum(minkh=1e-4, maxkh=1e3, npoints = 200)
s8 = np.array(results.get_sigma8())
# Out:
# Note: redshifts have been re-sorted (earliest first)

# %%
reload(compos)
k = kh * h
nlp_class_0 = compos.halofit(om0 = om0, H=H0, T_CMB=TCMB, omq=omq, Z=0, sigma8=s8[-1])
nlpk_compos_0 = nlp_class_0.nlpowerspec(k)
nlp_class_2 = compos.halofit(om0 = om0, H=H0, T_CMB=TCMB, omq=omq, Z=2, sigma8=s8[-1])
nlpk_compos_2 = nlp_class_2.nlpowerspec(k)
nlp_class_4 = compos.halofit(om0 = om0, H=H0, T_CMB=TCMB, omq=omq, Z=4, sigma8=s8[-1])
nlpk_compos_4 = nlp_class_4.nlpowerspec(k)

# %%
from matplotlib import gridspec

fig = plt.figure(figsize=(7,7))
gs = gridspec.GridSpec(2, 1, height_ratios=[4, 1]) 

ax1 = plt.subplot(gs[0])
ax1.loglog(kh, nlpk_camb[0], color = 'C0', label='CAMB, Z=0')
ax1.loglog(kh, nlpk_compos_0*h**3, color = 'C1', label='COMPOS, Z=0')

ax1.loglog(kh, nlpk_camb[1], color = 'C2', label='CAMB, Z=2')
ax1.loglog(kh, nlpk_compos_2*h**3, color = 'C3', label='COMPOS, Z=2')

ax1.loglog(kh, nlpk_camb[2], color = 'C4', label='CAMB, Z=4')
ax1.loglog(kh, nlpk_compos_4*h**3, color = 'C5', label='COMPOS, Z=4')
ax1.legend()
ax1.grid()
ax1.xaxis.set_ticklabels([])
ax1.set_ylabel(r'$P(k)(\mathrm{h^{-1}Mpc})^3$',fontsize=12)
ax2 = plt.subplot(gs[1])
ax2.semilogx(kh, (nlpk_camb[0]-(nlpk_compos_0*h**3)) / nlpk_camb[0]*100, color='C0', label='Z=0')
ax2.semilogx(kh, (nlpk_camb[1]-(nlpk_compos_2*h**3)) / nlpk_camb[1]*100, color='C2', label='Z=2')
ax2.semilogx(kh, (nlpk_camb[2]-(nlpk_compos_4*h**3)) / nlpk_camb[2]*100, color='C4', label='Z=4')
ax2.legend()
ax2.set_ylim(-5, 5)
ax2.grid()
ax2.set_xlabel(r'$k(\mathrm{h^{-1}Mpc})$',fontsize=12)
ax2.set_ylabel(r'$\Delta(\%)$')
plt.subplots_adjust(hspace=0)
